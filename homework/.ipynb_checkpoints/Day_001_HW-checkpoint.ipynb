# %% [markdown]
# ## 作業1
#
# ### 資料集：1985-2016年自殺率概況
# [Suicide Rates Overview 1985 to 2016](https://www.kaggle.com/russellyates88/suicide-rates-overview-1985-to-2016)
#
# 1. 你選的這組資料為何重要<br>
#     生命可貴，預防自殺是全球性議題。<br>
#     這組資料集整合了四個不同組織與時間的資料。使用者在進行自殺率的研究時，可能不會想到這些來自其他單位有相關的變數。將不同單位的變數整合為一個資料集，也減少了使用者自行蒐集資料的時間。<p>
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)<br>
#    提供者為[Rusty](https://www.kaggle.com/russellyates88) ，整合了以下四個單位的資料：
#      * United Nations Development Program (2018)
#      * World Bank (2018)
#      * Szamil (2017) (kaggle)
#      * World Health Organization (2018)
#
# <P>
# 3. 蒐集而來的資料型態為何<br>
#    屬於結構化資料(.csv)，包含以下欄位：<br>
#        country,year,sex,age,suicides_no,population,suicides/100k pop,country-year,HDI for year,gdp_for_year,gdp_per_capita,generation
#
# 4. 這組資料想解決的問題如何評估<br>
#    透過與自殺率相關的社會經濟、年份和國家等變數，比較不同地區、不同年代及不同年齡層之下的自殺率，探討自殺率的高低是否與社經發展程度有關，得到準確的分析並預測，進一步加以預防，減少自殺的憾事發生。

# %% [markdown]
# ## 作業2
#
# ### 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)<br>
#     提升業績，假設發放折價券能提升營業額<p>
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)<br>
#     由載客系統中紀錄每位顧客交易資料，包含顧客ID、里程數、上下車的時間、地點、費用及是否使用折價券<p>
#
# 3. 蒐集而來的資料型態為何<br>
#     蒐集的數據為結構化資料<p>
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)<br>
#     比較每一顧客在發放折價券前、後叫車的頻率，觀察叫車頻率是否有提升，進一步計算發放折價券後的營業額是否有所提升。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = MSE = sum((y - yp) ** 2) / len(y)
    return mse

def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 186.689
# The Mean absolute error is 10.978
